# %%
import pandas as pd

# %%
tr_0 = pd.read_csv('transaction_0.csv')
tr_1 = pd.read_csv('transaction_1.csv')
tr_2 = pd.read_csv('transaction_2.csv')

# %%
tr_0
# Out:
#    Name        date  amount     result
# 0  Kang  2017-01-01     500  confirmed
# 1   Kim  2017-01-03     700  confirmed
# 2  Choi  2017-01-05     800  confirmed
# 3  Park  2017-01-07     500   canceled
# 4   Lee  2017-01-09     700  confirmed
# 5  Yoon  2017-01-10     200   canceled

# %%
tr_1
# Out:
#    Name  amount        date     result
# 0  Park     400  2015-01-01  confirmed
# 1   Kim     800  2015-01-02  confirmed
# 2  Choi     500  2015-01-05   canceled

# %%
tr_2
# Out:
#     Name  amount        date     result
# 0    Lee     400  2016-01-01  confirmed
# 1  Young     300  2016-01-05  confirmed
# 2    Kim     700  2016-01-06  confirmed
# 3   Choi     800  2016-01-07   canceled
# 4   Yoon     500  2016-01-11  confirmed
# 5   Jang     200  2016-01-13  confirmed
# 6   Park     300  2016-01-20   canceled

# %%
pd.concat([tr_0, tr_1, tr_2], sort=True)
# Out:
#     Name  amount        date     result
# 0   Kang     500  2017-01-01  confirmed
# 1    Kim     700  2017-01-03  confirmed
# 2   Choi     800  2017-01-05  confirmed
# 3   Park     500  2017-01-07   canceled
# 4    Lee     700  2017-01-09  confirmed
# 5   Yoon     200  2017-01-10   canceled
# 0   Park     400  2015-01-01  confirmed
# 1    Kim     800  2015-01-02  confirmed
# 2   Choi     500  2015-01-05   canceled
# 0    Lee     400  2016-01-01  confirmed
# 1  Young     300  2016-01-05  confirmed
# 2    Kim     700  2016-01-06  confirmed
# 3   Choi     800  2016-01-07   canceled
# 4   Yoon     500  2016-01-11  confirmed
# 5   Jang     200  2016-01-13  confirmed
# 6   Park     300  2016-01-20   canceled

# %%
tr_0.append([tr_1, tr_2], sort=True)
# Out:
#     Name  amount        date     result
# 0   Kang     500  2017-01-01  confirmed
# 1    Kim     700  2017-01-03  confirmed
# 2   Choi     800  2017-01-05  confirmed
# 3   Park     500  2017-01-07   canceled
# 4    Lee     700  2017-01-09  confirmed
# 5   Yoon     200  2017-01-10   canceled
# 0   Park     400  2015-01-01  confirmed
# 1    Kim     800  2015-01-02  confirmed
# 2   Choi     500  2015-01-05   canceled
# 0    Lee     400  2016-01-01  confirmed
# 1  Young     300  2016-01-05  confirmed
# 2    Kim     700  2016-01-06  confirmed
# 3   Choi     800  2016-01-07   canceled
# 4   Yoon     500  2016-01-11  confirmed
# 5   Jang     200  2016-01-13  confirmed
# 6   Park     300  2016-01-20   canceled

# %%
how = [
    {'how':'무통장 입금', 'installment':"없음"},
    {'how':'카드결제', 'installment':"0개월"},
    {'how':'카드결제', 'installment':"3개월"}
]

# %%
how = pd.DataFrame(how, index=['Park', 'Kim', 'Choi'])
how
# Out:
#          how installment
# Park  무통장 입금          없음
# Kim     카드결제         0개월
# Choi     NaN         NaN

# %%
tr_1 = tr_1.set_index('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1440/1278069883.py in <module>
# ----> 1 tr_1 = tr_1.set_index('Name')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['Name'] are in the columns"

# %%
pd.concat([tr_1, how], axis=1)
# Out:
#       amount        date     result     how installment
# Park     400  2015-01-01  confirmed  무통장 입금          없음
# Kim      800  2015-01-02  confirmed    카드결제         0개월
# Choi     500  2015-01-05   canceled     NaN         NaN
