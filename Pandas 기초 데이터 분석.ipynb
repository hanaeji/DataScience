# %%
import pandas as pd

# %%
company = pd.read_csv('company.csv')

# %%
type(company)
# Out:
# pandas.core.frame.DataFrame

# %%
print(company.shape)
# Out:
# (2022, 11)

# %%
company.head(10)
# Out:
#     분류       회사명    종목코드                   업종  \
# 0  코스피       두산우  000155  회사 본부 및 경영 컨설팅 서비스업
# 1  코스피     한화3우B  00088K          기타 화학제품 제조업
# 2  코스피    S-Oil우  010955           석유 정제품 제조업
# 3  코스피     LG화학우  051915          기초 화학물질 제조업
# 4  코스피   한국금융지주우  071055               기타 금융업
# 5  코스피       GS우  078935               기타 금융업
# 6  코스피  SK이노베이션우  096775               기타 금융업
# 7  코스피    코오롱인더우  120115             화학섬유 제조업
# 8  코스피     삼성화재우  000815                  보험업
# 9  코스피    현대차2우B  005387    자동차용 엔진 및 자동차 제조업
#
#                                                 주요제품         상장일  결산월  \
# 0  청주,소주,인쇄회로기판(인쇄회로용동박적층판),관련전자부품,기계 제조,판매/출판사업,...  1973-06-29  12월
# 1  화약,화공품,자동선반류,공작기계 제조,전자교환기,건설,정보통신,종합무역/임직원 및 ...  1976-06-24  12월
# 2                  석유제품,가스,윤활기유,윤활유,그리스,석유화학제품 제조,도매  1987-05-27  12월
# 3          유화/기능/합성수지,재생섬유소,산업재,리튬이온전지,평광판,PVC 제조,도매  2001-04-25  12월
# 4                                             금융지주회사  2003-07-21  12월
# ...

# %%
company.tail(7)
# Out:
#        분류        회사명    종목코드                        업종               주요제품  \
# 2015  코스닥         코센  009730                 1차 철강 제조업  스테인리스파이프, 선박용배관제작
# 2016  코스닥         카스  016920          기계장비 및 관련 물품 도매업           전자저울,로드셀
# 2017  코스닥     하이록코리아  013030                 1차 철강 제조업               관이음쇠
# 2018  코스닥  SBI인베스트먼트  019550               신탁업 및 집합투자업              벤처캐피탈
# 2019  코스닥      엠벤처투자  019590               신탁업 및 집합투자업              벤처캐피탈
# 2020  코스닥      제미니투자  019570               신탁업 및 집합투자업              벤처캐피탈
# 2021  코스닥        모헨즈  006920  시멘트, 석회, 플라스터 및 그 제품 제조업                레미콘
#
#              상장일  결산월                대표자명                       홈페이지     지역  \
# 2015  1990-07-27  12월  이제원 , 박형채 (각자대표이사)    http://www.kossen.co.kr   전라북도
# 2016  1990-01-04  12월                 김태인       http://www.cas.co.kr    경기도
# 2017  1989-12-15  12월     문휴건, 문창환 각자대표이사      http://www.hy-lok.com  부산광역시
# ...

# %%
company['분류']
# Out:
# 0       코스피
# 1       코스피
# 2       코스피
# 3       코스피
# 4       코스피
#        ...
# 2017    코스닥
# 2018    코스닥
# 2019    코스닥
# 2020    코스닥
# 2021    코스닥
# Name: 분류, Length: 2022, dtype: object

# %%
company[['분류', '회사명', '종목코드']].tail()
# Out:
#        분류        회사명    종목코드
# 2017  코스닥     하이록코리아  013030
# 2018  코스닥  SBI인베스트먼트  019550
# 2019  코스닥      엠벤처투자  019590
# 2020  코스닥      제미니투자  019570
# 2021  코스닥        모헨즈  006920

# %%
company.loc[100:106].head()
# Out:
#       분류    회사명    종목코드            업종  \
# 100  코스피    휴비스  079980      화학섬유 제조업
# 101  코스피  케이탑리츠  145270  부동산 임대 및 공급업
# 102  코스피  GS리테일  007070        종합 소매업
# 103  코스피   인터지스  129260     도로 화물 운송업
# 104  코스피    삼양사  145990     기타 식품 제조업
#
#                                               주요제품         상장일  결산월  \
# 100  합성섬유(폴리에스테르원사,원면),재생섬유,폴리에스텔 원사,원면,고상칩 제조,도소매  2012-02-23  12월
# 101                                         부동산 임대  2012-01-31  12월
# 102               체인화 편의점,슈퍼마켓,마트,전자상거래/부동산(빌딩) 임대  2011-12-23  12월
# 103                                     화물운송,알선,하역  2011-12-16  12월
# 104                                             설탕  2011-12-05  12월
#
#                  대표자명                        홈페이지     지역        구글코드
# 100               신유동        http://www.huvis.com  서울특별시  KRX:079980
# 101  이명식, 송명곤(각자대표이사)  http://www.ktopreits.co.kr  서울특별시  KRX:145270
# 102               허연수     http://www.gsretail.com  서울특별시  KRX:007070
# ...

# %%
ids = [1, 5, 100, 2010]
columns = ['분류', '회사명', '종목코드']
company.loc[ids][['분류', '회사명', '종목코드']]
# Out:
#        분류    회사명    종목코드
# 1     코스피  한화3우B  00088K
# 5     코스피    GS우  078935
# 100   코스피    휴비스  079980
# 2010  코스닥    글로본  019660

# %%
company[company['분류'] == '코스피']
# Out:
#       분류      회사명    종목코드                   업종  \
# 0    코스피      두산우  000155  회사 본부 및 경영 컨설팅 서비스업
# 1    코스피    한화3우B  00088K          기타 화학제품 제조업
# 2    코스피   S-Oil우  010955           석유 정제품 제조업
# 3    코스피    LG화학우  051915          기초 화학물질 제조업
# 4    코스피  한국금융지주우  071055               기타 금융업
# ..   ...      ...     ...                  ...
# 777  코스피     유한양행  000100              의약품 제조업
# 778  코스피   CJ대한통운  000120            도로 화물 운송업
# 779  코스피    메리츠화재  000060                  보험업
# 780  코스피       경방  000050         방적 및 가공사 제조업
# 781  코스피    유수홀딩스  000700  회사 본부 및 경영 컨설팅 서비스업
#
#                                                   주요제품         상장일  결산월  \
# 0    청주,소주,인쇄회로기판(인쇄회로용동박적층판),관련전자부품,기계 제조,판매/출판사업,...  1973-06-29  12월
# 1    화약,화공품,자동선반류,공작기계 제조,전자교환기,건설,정보통신,종합무역/임직원 및 ...  1976-06-24  12월
# 2                    석유제품,가스,윤활기유,윤활유,그리스,석유화학제품 제조,도매  1987-05-27  12월
# 3            유화/기능/합성수지,재생섬유소,산업재,리튬이온전지,평광판,PVC 제조,도매  2001-04-25  12월
# ...

# %%
company[company['분류'] == '코스닥'][columns]
# Out:
#        분류        회사명    종목코드
# 782   코스닥       컬러레이  900310
# 783   코스닥  엔에이치스팩12호  273060
# 784   코스닥       모트렉스  118990
# 785   코스닥     데이타솔루션  263800
# 786   코스닥       지니언스  263860
# ...   ...        ...     ...
# 2017  코스닥     하이록코리아  013030
# 2018  코스닥  SBI인베스트먼트  019550
# 2019  코스닥      엠벤처투자  019590
# 2020  코스닥      제미니투자  019570
# 2021  코스닥        모헨즈  006920
#
# [1240 rows x 3 columns]

# %%
company[company['회사명'] == '삼성전자']
# Out:
#       분류   회사명    종목코드              업종  \
# 714  코스피  삼성전자  005930  통신 및 방송 장비 제조업
#
#                                                   주요제품         상장일  결산월  \
# 714  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11  12월
#
#               대표자명                  홈페이지   지역        구글코드
# 714  권오현, 윤부근, 신종균  http://www.sec.co.kr  경기도  KRX:005930

# %%
company[company['종목코드'] == '035720']
# Out:
#      분류  회사명    종목코드                                업종             주요제품  \
# 16  코스피  카카오  035720  자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업  인터넷 서비스(인터넷 광고)
#
#            상장일  결산월 대표자명                      홈페이지       지역        구글코드
# 16  2017-07-10  12월  임지훈  http://www.kakaocorp.com  제주특별자치도  KRX:035720

# %%
company.iloc[0].values # 행에 접근
# Out:
# array(['코스피', '두산우', '000155', '회사 본부 및 경영 컨설팅 서비스업',
#        '청주,소주,인쇄회로기판(인쇄회로용동박적층판),관련전자부품,기계 제조,판매/출판사업,상가임대,외식사업(KFC)',
#        '1973-06-29', '12월', '박정원, 이재경', 'http://www.doosancorp.co.kr',
#        '서울특별시', 'KRX:000155'], dtype=object)

# %%
# Not a Number == NaN
company[company['종목코드'].isnull()]
# Out:
#      분류  회사명 종목코드   업종 주요제품  상장일  결산월 대표자명 홈페이지   지역 구글코드
# 14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
company[company['종목코드'].notnull()]
# Out:
#        분류        회사명    종목코드                        업종  \
# 0     코스피        두산우  000155       회사 본부 및 경영 컨설팅 서비스업
# 1     코스피      한화3우B  00088K               기타 화학제품 제조업
# 2     코스피     S-Oil우  010955                석유 정제품 제조업
# 3     코스피      LG화학우  051915               기초 화학물질 제조업
# 4     코스피    한국금융지주우  071055                    기타 금융업
# ...   ...        ...     ...                       ...
# 2017  코스닥     하이록코리아  013030                 1차 철강 제조업
# 2018  코스닥  SBI인베스트먼트  019550               신탁업 및 집합투자업
# 2019  코스닥      엠벤처투자  019590               신탁업 및 집합투자업
# 2020  코스닥      제미니투자  019570               신탁업 및 집합투자업
# 2021  코스닥        모헨즈  006920  시멘트, 석회, 플라스터 및 그 제품 제조업
#
#                                                    주요제품         상장일  결산월  \
# 0     청주,소주,인쇄회로기판(인쇄회로용동박적층판),관련전자부품,기계 제조,판매/출판사업,...  1973-06-29  12월
# 1     화약,화공품,자동선반류,공작기계 제조,전자교환기,건설,정보통신,종합무역/임직원 및 ...  1976-06-24  12월
# 2                     석유제품,가스,윤활기유,윤활유,그리스,석유화학제품 제조,도매  1987-05-27  12월
# ...

# %%
company = company.dropna()

# %%
company
# Out:
#        분류        회사명    종목코드                        업종  \
# 0     코스피        두산우  000155       회사 본부 및 경영 컨설팅 서비스업
# 1     코스피      한화3우B  00088K               기타 화학제품 제조업
# 2     코스피     S-Oil우  010955                석유 정제품 제조업
# 3     코스피      LG화학우  051915               기초 화학물질 제조업
# 4     코스피    한국금융지주우  071055                    기타 금융업
# ...   ...        ...     ...                       ...
# 2017  코스닥     하이록코리아  013030                 1차 철강 제조업
# 2018  코스닥  SBI인베스트먼트  019550               신탁업 및 집합투자업
# 2019  코스닥      엠벤처투자  019590               신탁업 및 집합투자업
# 2020  코스닥      제미니투자  019570               신탁업 및 집합투자업
# 2021  코스닥        모헨즈  006920  시멘트, 석회, 플라스터 및 그 제품 제조업
#
#                                                    주요제품         상장일  결산월  \
# 0     청주,소주,인쇄회로기판(인쇄회로용동박적층판),관련전자부품,기계 제조,판매/출판사업,...  1973-06-29  12월
# 1     화약,화공품,자동선반류,공작기계 제조,전자교환기,건설,정보통신,종합무역/임직원 및 ...  1976-06-24  12월
# 2                     석유제품,가스,윤활기유,윤활유,그리스,석유화학제품 제조,도매  1987-05-27  12월
# ...

# %%
company[company['회사명'].isin(['삼성전자', '한화'])]
# Out:
#       분류   회사명    종목코드              업종  \
# 671  코스피    한화  000880     기타 화학제품 제조업
# 714  코스피  삼성전자  005930  통신 및 방송 장비 제조업
#
#                                                   주요제품         상장일  결산월  \
# 671  화약,화공품,자동선반류,공작기계 제조,전자교환기,건설,정보통신,종합무역/임직원 및 ...  1976-06-24  12월
# 714  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11  12월
#
#                    대표자명                         홈페이지     지역        구글코드
# 671  최양수, 이태종, 김연철, 이민석  http://www.hanwhacorp.co.kr  서울특별시  KRX:000880
# 714       권오현, 윤부근, 신종균         http://www.sec.co.kr    경기도  KRX:005930

# %%
company[company['회사명'].str.contains('한화')]
# Out:
#       분류         회사명    종목코드                업종  \
# 1    코스피       한화3우B  00088K       기타 화학제품 제조업
# 12   코스피      한화케미칼우  009835       기초 화학물질 제조업
# 150  코스피        한화생명  088350               보험업
# 383  코스피  한화갤러리아타임월드  027390            종합 소매업
# 575  코스피       한화테크윈  012450  항공기,우주선 및 부품 제조업
# 581  코스피      한화투자증권  003530        금융 지원 서비스업
# 589  코스피        대한화섬  003830          화학섬유 제조업
# 671  코스피          한화  000880       기타 화학제품 제조업
# 706  코스피      한화손해보험  000370               보험업
# 727  코스피       한화케미칼  009830       기초 화학물질 제조업
# 806  코스닥   한화에이스스팩3호  264290        금융 지원 서비스업
# 966  코스닥   한화에이스스팩2호  219860        금융 지원 서비스업
#
#                                                   주요제품         상장일  결산월  \
# 1    화약,화공품,자동선반류,공작기계 제조,전자교환기,건설,정보통신,종합무역/임직원 및 ...  1976-06-24  12월
# 12   합성수지,유화부문(LDPE,LLDPE)제품 제조,플라스틱가공품(PVC),CA,무기화...  1974-06-19  12월
# 150                                               생명보험  2010-03-17  12월
# ...

# %%
im
